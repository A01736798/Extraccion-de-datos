# %% [markdown]
# <a href="https://colab.research.google.com/github/A01736798/Extraccion-de-datos/blob/main/2_Extraccion_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()

# %%
df= pd.read_csv("CountryTable.csv")

# %%
df.head(5)
# Out:
#   code         name      continent                     region  surface_area  \
# 0  ABW        Aruba  North America                  Caribbean         193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia      652090.0
# 2  AGO       Angola         Africa             Central Africa     1246700.0
# 3  AIA     Anguilla  North America                  Caribbean          96.0
# 4  ALB      Albania         Europe            Southern Europe       28748.0
#
#    independence_year  population  life_expectancy     gnp  gnp_old  \
# 0                NaN      103000             78.4   828.0    793.0
# 1             1919.0    22720000             45.9  5976.0      NaN
# 2             1975.0    12878000             38.3  6648.0   7984.0
# 3                NaN        8000             76.1    63.2      NaN
# 4             1912.0     3401200             71.6  3205.0   2500.0
#
#               local_name                               government_form  \
# ...

# %%
filtro_1=df[df["continent"]=="North America"]
filtro_1
# Out:
#     code                              name      continent           region  \
# 0    ABW                             Aruba  North America        Caribbean
# 3    AIA                          Anguilla  North America        Caribbean
# 6    ANT              Netherlands Antilles  North America        Caribbean
# 13   ATG               Antigua and Barbuda  North America        Caribbean
# 24   BHS                           Bahamas  North America        Caribbean
# 27   BLZ                            Belize  North America  Central America
# 28   BMu                           Bermuda  North America    North America
# 31   BRB                          Barbados  North America        Caribbean
# 37   CAN                            Canada  North America    North America
# 50   CRI                        Costa Rica  North America  Central America
# 51   CuB                              Cuba  North America        Caribbean
# ...

# %%
filtro_2=df.iloc[0:12,:]
filtro_2
# Out:
#    code                  name      continent                     region  \
# 0   ABW                 Aruba  North America                  Caribbean
# 1   AFG           Afghanistan           Asia  Southern and Central Asia
# 2   AGO                Angola         Africa             Central Africa
# 3   AIA              Anguilla  North America                  Caribbean
# 4   ALB               Albania         Europe            Southern Europe
# 5   AND               Andorra         Europe            Southern Europe
# 6   ANT  Netherlands Antilles  North America                  Caribbean
# 7   ARE  united Arab Emirates           Asia                Middle East
# 8   ARG             Argentina  South America              South America
# 9   ARM               Armenia           Asia                Middle East
# 10  ASM        American Samoa        Oceania                  Polynesia
# 11  ATA            Antarctica     Antarctica                 Antarctica
#
# ...

# %%
filtro_3=df.iloc[:,6:10]
filtro_3
# Out:
#      population  life_expectancy       gnp   gnp_old
# 0        103000             78.4     828.0     793.0
# 1      22720000             45.9    5976.0       NaN
# 2      12878000             38.3    6648.0    7984.0
# 3          8000             76.1      63.2       NaN
# 4       3401200             71.6    3205.0    2500.0
# ..          ...              ...       ...       ...
# 234    18112000             59.8    6041.0    5729.0
# 235    10640000             72.4   17000.0       NaN
# 236    40377000             51.1  116729.0  129092.0
# 237     9169000             37.2    3377.0    3922.0
# 238    11669000             37.8    5951.0    8670.0
#
# [239 rows x 4 columns]

# %%
df= pd.read_csv("CountryTable.csv",index_col=2)
df

# %%
filtro_4= df.loc[["North America","Europe",],["gnp","gnp_old","life_expectancy"]]
filtro_4
# Out:
#                     gnp   gnp_old  life_expectancy
# continent
# North America     828.0     793.0             78.4
# North America      63.2       NaN             76.1
# North America    1941.0       NaN             74.7
# North America     612.0     584.0             70.5
# North America    3527.0    3347.0             71.1
# ...                 ...       ...              ...
# Europe          19756.0   18202.0             74.9
# Europe         226492.0  227757.0             79.6
# Europe          42168.0   49677.0             66.0
# Europe              9.0       NaN              NaN
# Europe          17000.0       NaN             72.4
#
# [83 rows x 3 columns]

# %%
filtro_5= df.head(12)
filtro_5
# Out:
#               code                  name                     region  \
# continent
# North America  ABW                 Aruba                  Caribbean
# Asia           AFG           Afghanistan  Southern and Central Asia
# Africa         AGO                Angola             Central Africa
# North America  AIA              Anguilla                  Caribbean
# Europe         ALB               Albania            Southern Europe
# Europe         AND               Andorra            Southern Europe
# North America  ANT  Netherlands Antilles                  Caribbean
# Asia           ARE  united Arab Emirates                Middle East
# South America  ARG             Argentina              South America
# Asia           ARM               Armenia                Middle East
# Oceania        ASM        American Samoa                  Polynesia
# Antarctica     ATA            Antarctica                 Antarctica
#
# ...

# %%
filtro_6= df[df["life_expectancy"]>70]
filtro_6
# Out:
#               code                              name           region  \
# continent
# North America  ABW                             Aruba        Caribbean
# North America  AIA                          Anguilla        Caribbean
# Europe         ALB                           Albania  Southern Europe
# Europe         AND                           Andorra  Southern Europe
# North America  ANT              Netherlands Antilles        Caribbean
# ...            ...                               ...              ...
# North America  VCT  Saint Vincent and the Grenadines        Caribbean
# South America  VEN                         Venezuela    South America
# North America  VGB           Virgin Islands, British        Caribbean
# North America  VIR              Virgin Islands, u.S.        Caribbean
# Europe         YuG                        Yugoslavia  Southern Europe
#
#                surface_area  independence_year  population  life_expectancy  \
# continent
# ...

# %%
df= pd.read_csv("CountryTable.csv")

# %%
filtro_7= df[(df["name"]=="Mexico") & (df["continent"]=="North America")]
filtro_7
# Out:
#     code    name      continent           region  surface_area  \
# 135  MEX  Mexico  North America  Central America     1958201.0
#
#      independence_year  population  life_expectancy       gnp   gnp_old  \
# 135             1810.0    98881000             71.5  414972.0  401461.0
#
#     local_name   government_form        head_of_state  capital code2
# 135     Mexico  Federal Republic  Vicente Fox Quesada   2515.0    MX

# %%
filtro_8= df[(df["continent"]=="North America") | (df["region"]=="Southern Europe")]
filtro_8
# Out:
#     code                              name      continent           region  \
# 0    ABW                             Aruba  North America        Caribbean
# 3    AIA                          Anguilla  North America        Caribbean
# 4    ALB                           Albania         Europe  Southern Europe
# 5    AND                           Andorra         Europe  Southern Europe
# 6    ANT              Netherlands Antilles  North America        Caribbean
# 13   ATG               Antigua and Barbuda  North America        Caribbean
# 24   BHS                           Bahamas  North America        Caribbean
# 25   BIH            Bosnia and Herzegovina         Europe  Southern Europe
# 27   BLZ                            Belize  North America  Central America
# 28   BMu                           Bermuda  North America    North America
# 31   BRB                          Barbados  North America        Caribbean
# ...

# %%
filtro_9= df[~(df["region"] == "Caribbean") & ~(df["gnp"]< 414900.0)& (df["continent"]=="North America")]
filtro_9
# Out:
#     code           name      continent           region  surface_area  \
# 37   CAN         Canada  North America    North America     9970610.0
# 135  MEX         Mexico  North America  Central America     1958201.0
# 223  uSA  united States  North America    North America     9363520.0
#
#      independence_year  population  life_expectancy        gnp    gnp_old  \
# 37              1867.0    31147000             79.4   598862.0   625626.0
# 135             1810.0    98881000             71.5   414972.0   401461.0
# 223             1776.0   278357000             77.1  8510700.0  8110900.0
#
#         local_name                      government_form        head_of_state  \
# 37          Canada  Constitutional Monarchy, Federation         Elisabeth II
# 135         Mexico                     Federal Republic  Vicente Fox Quesada
# 223  united States                     Federal Republic       George W. Bush
#
#      capital code2
# 37    1822.0    CA
# 135   2515.0    MX
# ...

# %%
filtro_9.to_csv("Entregable_paises_9.csv")

# %%
from google.colab import files
files.download("Entregable_paises_9.csv")
